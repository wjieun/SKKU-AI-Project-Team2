# %% [markdown]
# # 생명선 classification
#
# 생명선

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from PIL import Image
from tqdm.auto import tqdm

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/AI_Project/인지프 팀플/classification/data
# Out:
# /content/drive/MyDrive/Colab Notebooks/AI_Project/인지프 팀플/classification/data

# %%
df = pd.read_excel('label4.xlsx')
df = df[~df['label'].str.contains("-")]  # Filter out invalid entries

# %%
print(df)
# Out:
#      File Number  life head  heart label
# 0              1     0    0      0   000
# 1              2     0    0      0   000
# 2              5     0    1      0   010
# 3             12     0    0      1   001
# 4             13     0    1      0   010
# ..           ...   ...  ...    ...   ...
# 976         5353     0    0      1   001
# 977         5354     1    0      1   101
# 978         5366     0    0      0   000
# 979         5367     0    0      0   000
# 981         5385     0    0      1   001
#
# [927 rows x 5 columns]

# %%
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
def load_and_preprocess_images(image_df):
    images = []
    for idx, row in tqdm(image_df.iterrows(), total=image_df.shape[0]):
        image_path = os.path.join('./life', f"image{row['File Number']}.png")
        image = Image.open(image_path).resize((128, 128))
        image = np.array(image) / 255.0
        if image.ndim == 2 or image.shape[2] == 1:
            image = np.stack((image,)*3, axis=-1)  # Convert grayscale to RGB
        images.append(image)
    return np.array(images)

# %%
train_images = load_and_preprocess_images(train_df)
test_images = load_and_preprocess_images(test_df)
# Out:
#   0%|          | 0/741 [00:00<?, ?it/s]
#   0%|          | 0/186 [00:00<?, ?it/s]

# %%
train_labels = train_df['life'].values
test_labels = test_df['life'].values

# %%
# Initialize MobileNetV2 model with pretrained ImageNet weights
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))
base_model.trainable = False  # Freeze base model

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(8, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # 1 unit for binary classification
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['binary_accuracy'])

# %%
# Callbacks for early stopping and saving the best model
callbacks = [
    EarlyStopping(patience=5, verbose=1),
    ModelCheckpoint('best_model.h5', save_best_only=True, save_weights_only=True)
]

history = model.fit(
    train_images, train_labels,
    validation_data=(test_images, test_labels),
    batch_size=32,
    epochs=50,  # May increase if model is not overfitting
    callbacks=callbacks
)

# Load the best weights and unfreeze the base_model for fine-tuning
model.load_weights('best_model.h5')
base_model.trainable = True
# Out:
# Epoch 1/50
# 24/24 [==============================] - 16s 531ms/step - loss: 0.7266 - binary_accuracy: 0.6154 - val_loss: 0.6494 - val_binary_accuracy: 0.6452
# Epoch 2/50
# 24/24 [==============================] - 9s 388ms/step - loss: 0.6679 - binary_accuracy: 0.6194 - val_loss: 0.6305 - val_binary_accuracy: 0.6452
# Epoch 3/50
# 24/24 [==============================] - 11s 442ms/step - loss: 0.6556 - binary_accuracy: 0.6167 - val_loss: 0.6084 - val_binary_accuracy: 0.6452
# Epoch 4/50
# 24/24 [==============================] - 10s 438ms/step - loss: 0.6538 - binary_accuracy: 0.6464 - val_loss: 0.6214 - val_binary_accuracy: 0.6452
# Epoch 5/50
# 24/24 [==============================] - 10s 416ms/step - loss: 0.6357 - binary_accuracy: 0.6464 - val_loss: 0.5816 - val_binary_accuracy: 0.6452
# Epoch 6/50
# 24/24 [==============================] - 12s 529ms/step - loss: 0.5962 - binary_accuracy: 0.6586 - val_loss: 0.4800 - val_binary_accuracy: 0.7957
# Epoch 7/50
# 24/24 [==============================] - 12s 504ms/step - loss: 0.5726 - binary_accuracy: 0.7058 - val_loss: 0.4764 - val_binary_accuracy: 0.8118
# Epoch 8/50
# 24/24 [==============================] - 10s 406ms/step - loss: 0.5463 - binary_accuracy: 0.7126 - val_loss: 0.4713 - val_binary_accuracy: 0.8441
# Epoch 9/50
# 24/24 [==============================] - 12s 481ms/step - loss: 0.5314 - binary_accuracy: 0.7314 - val_loss: 0.4512 - val_binary_accuracy: 0.8387
# Epoch 10/50
# 24/24 [==============================] - 10s 419ms/step - loss: 0.5168 - binary_accuracy: 0.7625 - val_loss: 0.4482 - val_binary_accuracy: 0.8387
# Epoch 11/50
# 24/24 [==============================] - 9s 378ms/step - loss: 0.5012 - binary_accuracy: 0.7557 - val_loss: 0.4504 - val_binary_accuracy: 0.8441
# Epoch 12/50
# 24/24 [==============================] - 11s 447ms/step - loss: 0.4811 - binary_accuracy: 0.7814 - val_loss: 0.4631 - val_binary_accuracy: 0.7796
# Epoch 13/50
# 24/24 [==============================] - 9s 382ms/step - loss: 0.4707 - binary_accuracy: 0.7881 - val_loss: 0.4071 - val_binary_accuracy: 0.8441
# Epoch 14/50
# 24/24 [==============================] - 12s 496ms/step - loss: 0.4716 - binary_accuracy: 0.7935 - val_loss: 0.4044 - val_binary_accuracy: 0.8387
# Epoch 15/50
# 24/24 [==============================] - 8s 358ms/step - loss: 0.4598 - binary_accuracy: 0.7773 - val_loss: 0.4031 - val_binary_accuracy: 0.8441
# Epoch 16/50
# 24/24 [==============================] - 11s 476ms/step - loss: 0.4618 - binary_accuracy: 0.8016 - val_loss: 0.4043 - val_binary_accuracy: 0.8387
# Epoch 17/50
# 24/24 [==============================] - 10s 436ms/step - loss: 0.4625 - binary_accuracy: 0.7962 - val_loss: 0.3762 - val_binary_accuracy: 0.8495
# Epoch 18/50
# 24/24 [==============================] - 9s 381ms/step - loss: 0.4181 - binary_accuracy: 0.8097 - val_loss: 0.3756 - val_binary_accuracy: 0.8280
# Epoch 19/50
# 24/24 [==============================] - 12s 528ms/step - loss: 0.4529 - binary_accuracy: 0.7922 - val_loss: 0.3702 - val_binary_accuracy: 0.8495
# Epoch 20/50
# 24/24 [==============================] - 8s 355ms/step - loss: 0.4184 - binary_accuracy: 0.8151 - val_loss: 0.3899 - val_binary_accuracy: 0.8011
# Epoch 21/50
# 24/24 [==============================] - 11s 477ms/step - loss: 0.4444 - binary_accuracy: 0.8327 - val_loss: 0.3948 - val_binary_accuracy: 0.8065
# Epoch 22/50
# 24/24 [==============================] - 13s 574ms/step - loss: 0.4100 - binary_accuracy: 0.8273 - val_loss: 0.3616 - val_binary_accuracy: 0.8495
# Epoch 23/50
# 24/24 [==============================] - 8s 343ms/step - loss: 0.4260 - binary_accuracy: 0.8340 - val_loss: 0.3703 - val_binary_accuracy: 0.8387
# Epoch 24/50
# 24/24 [==============================] - 11s 450ms/step - loss: 0.4240 - binary_accuracy: 0.8300 - val_loss: 0.3853 - val_binary_accuracy: 0.8172
# Epoch 25/50
# 24/24 [==============================] - 10s 413ms/step - loss: 0.3906 - binary_accuracy: 0.8273 - val_loss: 0.3537 - val_binary_accuracy: 0.8441
# Epoch 26/50
# 24/24 [==============================] - 9s 393ms/step - loss: 0.4301 - binary_accuracy: 0.8219 - val_loss: 0.3676 - val_binary_accuracy: 0.8441
# Epoch 27/50
# 24/24 [==============================] - 13s 565ms/step - loss: 0.4388 - binary_accuracy: 0.8205 - val_loss: 0.3708 - val_binary_accuracy: 0.8387
# Epoch 28/50
# 24/24 [==============================] - 9s 373ms/step - loss: 0.3955 - binary_accuracy: 0.8232 - val_loss: 0.3440 - val_binary_accuracy: 0.8495
# Epoch 29/50
# 24/24 [==============================] - 11s 476ms/step - loss: 0.4110 - binary_accuracy: 0.8408 - val_loss: 0.3565 - val_binary_accuracy: 0.8333
# Epoch 30/50
# 24/24 [==============================] - 12s 530ms/step - loss: 0.3925 - binary_accuracy: 0.8273 - val_loss: 0.3454 - val_binary_accuracy: 0.8495
# Epoch 31/50
# 24/24 [==============================] - 9s 378ms/step - loss: 0.3950 - binary_accuracy: 0.8502 - val_loss: 0.3521 - val_binary_accuracy: 0.8387
# Epoch 32/50
# 24/24 [==============================] - 12s 503ms/step - loss: 0.3945 - binary_accuracy: 0.8259 - val_loss: 0.4023 - val_binary_accuracy: 0.7957
# Epoch 33/50
# 24/24 [==============================] - 13s 532ms/step - loss: 0.3581 - binary_accuracy: 0.8340 - val_loss: 0.3545 - val_binary_accuracy: 0.8495
# Epoch 33: early stopping

# %%
# Evaluate the model on the test set.
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 6/6 [==============================] - 2s 258ms/step - loss: 0.3440 - binary_accuracy: 0.8495
# Test accuracy: 84.95%

# %%
from sklearn.metrics import f1_score

# Predict on the test set
test_predictions = model.predict(test_images)
test_predictions = (test_predictions > 0.5).astype("int32")  # Convert probabilities to binary predictions

# Calculate the F1 score
f1 = f1_score(test_labels, test_predictions)

print(f"F1 Score: {f1}")
# Out:
# 6/6 [==============================] - 3s 250ms/step
# F1 Score: 0.7543859649122807

# %%
# Recompile the model with a low learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),  # Low learning rate for fine-tuning
              loss='binary_crossentropy',
              metrics=['binary_accuracy'])

# %%
# Fine-tune the model
history_fine = model.fit(
    train_images, train_labels,
    validation_data=(test_images, test_labels),
    batch_size=32,
    epochs=20,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 63s 2s/step - loss: 3.1619 - binary_accuracy: 0.6275 - val_loss: 0.3566 - val_binary_accuracy: 0.8441
# Epoch 2/20
# 24/24 [==============================] - 43s 2s/step - loss: 2.3512 - binary_accuracy: 0.6316 - val_loss: 0.4415 - val_binary_accuracy: 0.7903
# Epoch 3/20
# 24/24 [==============================] - 43s 2s/step - loss: 1.9072 - binary_accuracy: 0.6559 - val_loss: 0.5777 - val_binary_accuracy: 0.7366
# Epoch 4/20
# 24/24 [==============================] - 44s 2s/step - loss: 1.4525 - binary_accuracy: 0.6964 - val_loss: 0.7845 - val_binary_accuracy: 0.6720
# Epoch 5/20
# 24/24 [==============================] - 43s 2s/step - loss: 1.2650 - binary_accuracy: 0.7274 - val_loss: 0.9975 - val_binary_accuracy: 0.6505
# Epoch 6/20
# 24/24 [==============================] - 44s 2s/step - loss: 1.4325 - binary_accuracy: 0.7449 - val_loss: 1.2007 - val_binary_accuracy: 0.6452
# Epoch 6: early stopping

# %%
# Evaluate the model on the test set.
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 6/6 [==============================] - 2s 251ms/step - loss: 1.2007 - binary_accuracy: 0.6452
# Test accuracy: 64.52%

# %%
from sklearn.metrics import f1_score

# Predict on the test set
test_predictions = model.predict(test_images)
test_predictions = (test_predictions > 0.5).astype("int32")  # Convert probabilities to binary predictions

# Calculate the F1 score
f1 = f1_score(test_labels, test_predictions)

print(f"F1 Score: {f1}")
# Out:
# 6/6 [==============================] - 2s 245ms/step
# F1 Score: 0.0

jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask365.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask365.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask371.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask371.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2436.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2436.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3728.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3728.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask4047.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask4047.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2350.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2350.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask417.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask417.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1659.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1659.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1881.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1881.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3066.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3066.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2378.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2378.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1671.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1671.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1117.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1117.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask359.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask359.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3700.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3700.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3714.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3714.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1103.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1103.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1665.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1665.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3072.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3072.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2387.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2387.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3099.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3099.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1856.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1856.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3927.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3927.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3933.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3933.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1842.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1842.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2393.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2393.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask167.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask167.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1329.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1329.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2620.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2620.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2146.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2146.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3258.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3258.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask601.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask601.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask615.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask615.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2152.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2152.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2634.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2634.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask173.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask173.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3502.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3502.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1315.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1315.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1473.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1473.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3264.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3264.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3270.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3270.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1467.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1467.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask629.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask629.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1301.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1301.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3516.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3516.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2608.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2608.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2185.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2185.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2191.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2191.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1498.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1498.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask198.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask198.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2807.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2807.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask826.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask826.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask832.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask832.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2813.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2813.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2754.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2754.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2032.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2032.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask775.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask775.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask761.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask761.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3338.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3338.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2026.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2026.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2740.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2740.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2998.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2998.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1249.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1249.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2768.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2768.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3476.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3476.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1261.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1261.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask749.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask749.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1507.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1507.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask991.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask991.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3310.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3310.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3304.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3304.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1513.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1513.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask985.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask985.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1275.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1275.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3462.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3462.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3489.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3489.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2797.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2797.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2783.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2783.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2973.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2973.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask952.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask952.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask946.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask946.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2967.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2967.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1739.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1739.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask577.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask577.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2230.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2230.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3648.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3648.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2556.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2556.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3890.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3890.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask211.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask211.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask205.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask205.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2542.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2542.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3884.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3884.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2224.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2224.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask563.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask563.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3112.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3112.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1705.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1705.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1063.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1063.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3674.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3674.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3660.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3660.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask239.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask239.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1077.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1077.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1711.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1711.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2218.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2218.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3106.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3106.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1922.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1922.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask61.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask61.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2595.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2595.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3853.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3853.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask2581.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask2581.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask3847.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask3847.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1088.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1088.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask1936.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask1936.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask75.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask75.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask588.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask588.jpg
#   inflating: /content/PLSU_4064_flip_rotate/Mask/mask49.jpg
#   inflating: /content/__MACOSX/PLSU_4064_flip_rotate/Mask/._mask49.jpg

# %% [markdown]
# # Sorting Data

# %%
## 파일 이름에서 숫자 부분을 추출하는 함수
def extract_number(file_name):
    numbers = re.findall(r'\d+', file_name)
    return int(numbers[0]) if numbers else 0


def list_files_in_directory(directory_path):
    items_in_directory = sorted(os.listdir(directory_path))
    files_in_directory = [item for item in items_in_directory if os.path.isfile(os.path.join(directory_path, item))]

    return files_in_directory

# %%
# 이미지와 마스크 파일 경로 가져오기 및 정렬
mask_directory = '/content/PLSU_4064_flip_rotate/Mask'
mask_files = list_files_in_directory(mask_directory)
sorted_mask_files = sorted(mask_files, key=extract_number)
print(sorted_mask_files)
print(len(sorted_mask_files))



image_directory = '/content/PLSU_4064_flip_rotate/img'
image_files = list_files_in_directory(image_directory)
sorted_image_files = sorted(image_files, key=extract_number)
print(sorted_image_files)
print(len(sorted_image_files))



# 이미지와 마스크 파일의 전체 경로 생성
image_paths = [os.path.join(image_directory, file_name) for file_name in sorted_image_files]
jpg', 'image176.jpg', 'image177.jpg', 'image178.jpg', 'image179.jpg', 'image180.jpg', 'image181.jpg', 'image182.jpg', 'image183.jpg', 'image184.jpg', 'image185.jpg', 'image186.jpg', 'image187.jpg', 'image188.jpg', 'image189.jpg', 'image190.jpg', 'image191.jpg', 'image192.jpg', 'image193.jpg', 'image194.jpg', 'image195.jpg', 'image196.jpg', 'image197.jpg', 'image198.jpg', 'image199.jpg', 'image200.jpg', 'image201.jpg', 'image202.jpg', 'image203.jpg', 'image204.jpg', 'image205.jpg', 'image206.jpg', 'image207.jpg', 'image208.jpg', 'image209.jpg', 'image210.jpg', 'image211.jpg', 'image212.jpg', 'image213.jpg', 'image214.jpg', 'image215.jpg', 'image216.jpg', 'image217.jpg', 'image218.jpg', 'image219.jpg', 'image220.jpg', 'image221.jpg', 'image222.jpg', 'image223.jpg', 'image224.jpg', 'image225.jpg', 'image226.jpg', 'image227.jpg', 'image228.jpg', 'image229.jpg', 'image230.jpg', 'image231.jpg', 'image232.jpg', 'image233.jpg', 'image234.jpg', 'image235.jpg', 'image236.jpg', 'image237.jpg', 'image238.jpg', 'image239.jpg', 'image240.jpg', 'image241.jpg', 'image242.jpg', 'image243.jpg', 'image244.jpg', 'image245.jpg', 'image246.jpg', 'image247.jpg', 'image248.jpg', 'image249.jpg', 'image250.jpg', 'image251.jpg', 'image252.jpg', 'image253.jpg', 'image254.jpg', 'image255.jpg', 'image256.jpg', 'image257.j ...
# 4064
# 이미지 경로 예시 : ['/content/PLSU_4064_flip_rotate/img/image1.jpg', '/content/PLSU_4064_flip_rotate/img/image2.jpg', '/content/PLSU_4064_flip_rotate/img/image3.jpg', '/content/PLSU_4064_flip_rotate/img/image4.jpg', '/content/PLSU_4064_flip_rotate/img/image5.jpg']
# 마스크 경로 예시 : ['/content/PLSU_4064_flip_rotate/Mask/mask1.jpg', '/content/PLSU_4064_flip_rotate/Mask/mask2.jpg', '/content/PLSU_4064_flip_rotate/Mask/mask3.jpg', '/content/PLSU_4064_flip_rotate/Mask/mask4.jpg', '/content/PLSU_4064_flip_rotate/Mask/mask5.jpg']

# %% [markdown]
# # Custom Dataset

# %%
#No augmentation, test시 이미지만 반환하도록 하는 코드
# class PalmDataset(Dataset):
#     def __init__(self, image_paths, mask_paths, size=(256, 256), mode='train'):
#         self.image_paths = image_paths
#         self.mask_paths = mask_paths
#         self.resize = size
#         self.mode = mode

#         # 기본 변환: 모든 모드에 적용
#         base_transform = [
#             A.Resize(*size),
#             A.Normalize(),
#             ToTensorV2()
#         ]

#         # Train 모드에만 적용될 추가적인 데이터 증강 변환
#         if mode == 'train':
#             self.transform = A.Compose([
#                 # data augmentation 적는 곳
#             ] + base_transform)
#         else:
#             # Validation 및 Test 모드에서는 기본 변환만 적용
#             self.transform = A.Compose(base_transform)

#     def __len__(self):
#         return len(self.image_paths)

#     def __getitem__(self, idx):
#         image = cv2.imread(self.image_paths[idx])
#         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#         if self.mode in ['train', 'val']:
#             mask = cv2.imread(self.mask_paths[idx], cv2.IMREAD_GRAYSCALE)
#             mask = mask / 255
#             augmented = self.transform(image=image, mask=mask)
#             return augmented['image'], augmented['mask']
#         else:
#             # 테스트 모드에서는 마스크 없이 이미지만 반환
#             return self.transform(image=image)['image']

# %%
from torch.utils.data import Dataset
import cv2
import albumentations as A
from albumentations.pytorch import ToTensorV2

class PalmDataset(Dataset):
    def __init__(self, image_paths, mask_paths, size=(256, 256), mode='train'):
        self.image_paths = image_paths
        self.mask_paths = mask_paths
        self.resize = size
        self.mode = mode

        # 기본 변환: 모든 모드에 적용
        base_transform = [
            A.Resize(*size),
            A.Normalize(),
            ToTensorV2()
        ]

        transform = [
            A.Resize(*size),
            ToTensorV2()
        ]
        self.normal_transform = A.Compose(transform)

        # Train 모드에만 적용될 추가적인 데이터 증강 변환
        if mode == 'train':
            self.transform = A.Compose([
                # data augmentation 적는 곳
            ] + base_transform)
        else:
            # Validation 및 Test 모드에서는 기본 변환만 적용
            self.transform = A.Compose(base_transform)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = cv2.imread(self.image_paths[idx])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.mask_paths[idx], cv2.IMREAD_GRAYSCALE)
        mask = mask / 255  # Normalize the mask to be [0, 1]

        # 변환 적용
        augmented = self.transform(image=image, mask=mask)
        augmented2 = self.normal_transform(image=image, mask=mask)
        return augmented['image'], augmented['mask'], augmented2['image']

# %% [markdown]
# # Data Lodaer

# %%
#train:val:test = 75%:15%:15%
train_image_paths, test_image_paths, train_mask_paths, test_mask_paths = train_test_split(image_paths, mask_paths, test_size=0.3, random_state=42)
test_image_paths, val_image_paths, test_mask_paths, val_mask_paths = train_test_split(test_image_paths, test_mask_paths, test_size=0.5, random_state=42)

train_dataset = PalmDataset(train_image_paths, train_mask_paths, size=(256,256),mode='train')
val_dataset = PalmDataset(val_image_paths, val_mask_paths, size=(256,256),mode='val')
test_dataset = PalmDataset(test_image_paths, test_mask_paths, size=(256,256),mode='test')

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

# 첫 번째 배치 가져오기
images, masks, images_ = next(iter(train_loader))

# 이미지와 마스크 시각화
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(10, 20))
for i in range(4):
    ax[i, 0].imshow(images_[i].permute(1, 2, 0))  # 이미지
    ax[i, 1].imshow(masks[i], cmap='gray')  # 마스크
    ax[i, 0].set_title("Image")
    ax[i, 1].set_title("Mask")
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Define Model

# %%
resnet = torchvision.models.resnet.resnet50(pretrained=True)

class ConvBlock(nn.Module):
    """
    Helper module that consists of a Conv -> BN -> ReLU
    """

    def __init__(self, in_channels, out_channels, padding=1, kernel_size=3, stride=1, with_nonlinearity=True):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, padding=padding, kernel_size=kernel_size, stride=stride)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()
        self.with_nonlinearity = with_nonlinearity

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        if self.with_nonlinearity:
            x = self.relu(x)
        return x


class Bridge(nn.Module):
    """
    This is the middle layer of the UNet which just consists of some
    """

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.bridge = nn.Sequential(
            ConvBlock(in_channels, out_channels),
            ConvBlock(out_channels, out_channels)
        )

    def forward(self, x):
        return self.bridge(x)


class UpBlockForUNetWithResNet50(nn.Module):
    """
    Up block that encapsulates one up-sampling step which consists of Upsample -> ConvBlock -> ConvBlock
    """

    def __init__(self, in_channels, out_channels, up_conv_in_channels=None, up_conv_out_channels=None,
                 upsampling_method="conv_transpose"):
        super().__init__()

        if up_conv_in_channels == None:
            up_conv_in_channels = in_channels
        if up_conv_out_channels == None:
            up_conv_out_channels = out_channels

        if upsampling_method == "conv_transpose":
            self.upsample = nn.ConvTranspose2d(up_conv_in_channels, up_conv_out_channels, kernel_size=2, stride=2)
        elif upsampling_method == "bilinear":
            self.upsample = nn.Sequential(
                nn.Upsample(mode='bilinear', scale_factor=2),
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1)
            )
        self.conv_block_1 = ConvBlock(in_channels, out_channels)
        self.conv_block_2 = ConvBlock(out_channels, out_channels)

    def forward(self, up_x, down_x):
        """

        :param up_x: this is the output from the previous up block
        :param down_x: this is the output from the down block
        :return: upsampled feature map
        """
        x = self.upsample(up_x)
        x = torch.cat([x, down_x], 1)
        x = self.conv_block_1(x)
        x = self.conv_block_2(x)
        return x


class UNetWithResnet50Encoder(nn.Module):
    DEPTH = 6

    def __init__(self, n_channels=3, n_classes=1):
        super().__init__()
        resnet = torchvision.models.resnet.resnet50(pretrained=True)
        down_blocks = []
        up_blocks = []

        # 입력 채널을 n_channels로 조정
        self.input_block = nn.Sequential(
            nn.Conv2d(n_channels, 64, kernel_size=7, stride=2, padding=3, bias=False),
            *list(resnet.children())[1:3]
        )
        self.input_pool = list(resnet.children())[3]

        for bottleneck in list(resnet.children()):
            if isinstance(bottleneck, nn.Sequential):
                down_blocks.append(bottleneck)
        self.down_blocks = nn.ModuleList(down_blocks)
        self.bridge = Bridge(2048, 2048)
        up_blocks.append(UpBlockForUNetWithResNet50(2048, 1024))
        up_blocks.append(UpBlockForUNetWithResNet50(1024, 512))
        up_blocks.append(UpBlockForUNetWithResNet50(512, 256))
        up_blocks.append(UpBlockForUNetWithResNet50(in_channels=128 + 64, out_channels=128,
                                                    up_conv_in_channels=256, up_conv_out_channels=128))
        up_blocks.append(UpBlockForUNetWithResNet50(in_channels=64 + 3, out_channels=64,
                                                    up_conv_in_channels=128, up_conv_out_channels=64))

        self.up_blocks = nn.ModuleList(up_blocks)

        self.out = nn.Conv2d(64, n_classes, kernel_size=1, stride=1)

    def forward(self, x, with_output_feature_map=False):
        pre_pools = dict()
        pre_pools[f"layer_0"] = x
        x = self.input_block(x)
        pre_pools[f"layer_1"] = x
        x = self.input_pool(x)

        for i, block in enumerate(self.down_blocks, 2):
            x = block(x)
            if i == (UNetWithResnet50Encoder.DEPTH - 1):
                continue
            pre_pools[f"layer_{i}"] = x

        x = self.bridge(x)

        for i, block in enumerate(self.up_blocks, 1):
            key = f"layer_{UNetWithResnet50Encoder.DEPTH - 1 - i}"
            x = block(x, pre_pools[key])
        output_feature_map = x
        x = self.out(x)
        del pre_pools
        if with_output_feature_map:
            return x, output_feature_map
        else:
            return x
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 100MB/s]

# %% [markdown]
# #Evaluate

# %%
# F-1 Score와 IoU 계산을 위한 함수
def calculate_f1_score(preds, labels):
    # 시그모이드 함수를 적용하여 확률로 변환
    preds = torch.sigmoid(preds)
    # 확률을 이진화 (0.5를 임계값으로 사용)
    preds = (preds > 0.5).float()

    # True Positives, False Positives, False Negatives 계산
    tp = (preds * labels).sum(dim=[1, 2, 3])
    fp = (preds * (1 - labels)).sum(dim=[1, 2, 3])
    fn = ((1 - preds) * labels).sum(dim=[1, 2, 3])

    # F1 Score 계산
    precision = tp / (tp + fp + 1e-6)
    recall = tp / (tp + fn + 1e-6)
    f1 = 2 * (precision * recall) / (precision + recall + 1e-6)

    # 배치 내 모든 이미지에 대한 F1 Score의 평균 반환
    return f1.mean().item()

def calculate_iou(preds, labels):
    # 시그모이드 함수를 적용하여 확률로 변환
    preds = torch.sigmoid(preds)
    # 확률을 이진화 (0.5를 임계값으로 사용)
    preds = (preds > 0.5).float()

    # True Positives, False Positives, False Negatives 계산
    intersection = (preds * labels).sum(dim=[1, 2, 3])  # 교집합
    total = (preds + labels).sum(dim=[1, 2, 3])  # 합집합
    union = total - intersection  # 합집합 - 교집합

    # IoU 계산
    iou = (intersection + 1e-6) / (union + 1e-6)  # 0으로 나누는 것을 방지하기 위한 작은 값 추가

    # 배치 내 모든 이미지에 대한 IoU의 평균 반환
    return iou.mean().item()

# %% [markdown]
# # Loss function

# %%
class DiceLoss(nn.Module):
    def __init__(self, smooth=1.):
        super(DiceLoss, self).__init__()
        self.smooth = smooth

    def forward(self, inputs, targets):
        # inputs : 모델 출력, targets : 실제 마스크
        inputs = torch.sigmoid(inputs)  # 시그모이드 함수를 적용하여 확률로 변환

        # 평탄화
        inputs = inputs.view(-1)
        targets = targets.view(-1)

        # Dice 계수 계산
        intersection = (inputs * targets).sum()
        dice = (2.*intersection + self.smooth)/(inputs.sum() + targets.sum() + self.smooth)

        # Dice 손실
        return 1 - dice

# %%
# !pip install -q -U segmentation-models-pytorch albumentations > /dev/null
import segmentation_models_pytorch as smp

# %% [markdown]
# #Train

# %%
import matplotlib.pyplot as plt

# 성능 기록을 위한 리스트 초기화
train_losses = []
val_losses = []
f1_scores_epochs = []
iou_scores_epochs = []



#하이퍼 파라미터
num_epochs = 50
learning_rate = 0.001
T_max = 50  # 학습률 주기

# 최상의 모델을 저장하기 위한 초기 설정
best_iou_score = 0.0
early_stopping_counter = 0
patience = 10  # 성능이 개선되지 않는 에포크 한계값

# model 초기화
model = UNetWithResnet50Encoder(n_channels=3, n_classes=1).to(device)
model = model.to(device)

#loss function과 optimizer 정리
criterion = smp.losses.FocalLoss(mode='binary')
optimizer = optim.AdamW(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=1e-4, amsgrad=False)

# CosineAnnealingLR 스케줄러 초기화
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max, eta_min=1e-6)

# training loop
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    for images, masks, _ in tqdm(train_loader):
        images = images.float().to(device)
        masks = masks.float().to(device).unsqueeze(1)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, masks)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
    #Learning Rate 조정
    scheduler.step()

    train_losses.append(epoch_loss / len(train_loader))

    # Validation loop
    model.eval()
    val_loss = 0
    iou_scores = []
    f1_scores = []
    with torch.no_grad():
        for images, masks, _ in tqdm(val_loader):  # val_loader는 검증 데이터셋에 대한 DataLoader입니다.
            images = images.float().to(device)
            masks = masks.float().to(device).unsqueeze(1)
            outputs = model(images)
            loss = criterion(outputs, masks)
            val_loss += loss.item()

            # F-1 Score와 IoU 계산
            f1 = calculate_f1_score(outputs, masks)
            iou = calculate_iou(outputs, masks)
            f1_scores.append(f1)
            iou_scores.append(iou)

    # 평균 IoU 및 손실 계산
    val_loss /= len(val_loader)
    avg_f1 = np.mean(f1_scores)
    avg_iou = np.mean(iou_scores)
    val_losses.append(val_loss)
    f1_scores_epochs.append(avg_f1)
    iou_scores_epochs.append(avg_iou)


    print(f'Epoch {epoch+1}, Loss: {epoch_loss/len(train_loader)}, Validation Loss: {val_loss}, Avg F-1: {avg_f1}, mIoU: {avg_iou}')

    # Early Stopping
    if avg_iou > best_iou_score:
        best_iou_score = avg_iou
        early_stopping_counter = 0
        # 가장 좋은 모델 저장
        torch.save(model.state_dict(), 'best_model.pth')
    else:
        early_stopping_counter += 1
        if early_stopping_counter >= patience:
            print("Early stopping triggered")
            break

# 학습 및 검증 손실 그래프
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train vs Validation Loss')
plt.legend()
plt.show()

# F-1 Score와 mIoU Score 그래프
plt.figure(figsize=(10, 5))
plt.plot(f1_scores_epochs, label='Average F-1 Score')
plt.plot(iou_scores_epochs, label='Mean IoU')
plt.xlabel('Epochs')
plt.ylabel('Score')
plt.title('F-1 Score vs Mean IoU')
plt.legend()
plt.show()
# Out:
# 100%|██████████| 89/89 [02:07<00:00,  1.43s/it]
# 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Epoch 1, Loss: 0.02044286211596781, Validation Loss: 0.008238828112371265, Avg F-1: 0.0, mIoU: 2.4483114424711516e-09
# 100%|██████████| 89/89 [01:51<00:00,  1.26s/it]
# 100%|██████████| 20/20 [00:22<00:00,  1.10s/it]
# Epoch 2, Loss: 0.005756706349928392, Validation Loss: 0.004544891859404742, Avg F-1: 0.3212930589914322, mIoU: 0.2027373466640711
# 100%|██████████| 89/89 [01:50<00:00,  1.24s/it]
# 100%|██████████| 20/20 [00:21<00:00,  1.09s/it]
# Epoch 3, Loss: 0.004058875290028165, Validation Loss: 0.004809922771528363, Avg F-1: 0.49022906869649885, mIoU: 0.3366121329367161
# 100%|██████████| 89/89 [01:49<00:00,  1.23s/it]
# 100%|██████████| 20/20 [00:21<00:00,  1.07s/it]
# Epoch 4, Loss: 0.003300552674977297, Validation Loss: 0.003335591359063983, Avg F-1: 0.6479715764522552, mIoU: 0.48353019803762437
# 100%|██████████| 89/89 [01:50<00:00,  1.24s/it]
# 100%|██████████| 20/20 [00:22<00:00,  1.15s/it]
# Epoch 5, Loss: 0.002916446230321955, Validation Loss: 0.003234173753298819, Avg F-1: 0.6273646950721741, mIoU: 0.4628559842705727
# 100%|██████████| 89/89 [01:50<00:00,  1.24s/it]
# 100%|██████████| 20/20 [00:21<00:00,  1.08s/it]
# Epoch 6, Loss: 0.0027239029112617287, Validation Loss: 0.0027629771386273204, Avg F-1: 0.6770082622766495, mIoU: 0.5160116896033287
# 100%|██████████| 89/89 [01:49<00:00,  1.23s/it]
# 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
#
/it]
# 100%|██████████| 20/20 [00:21<00:00,  1.09s/it]
# Epoch 20, Loss: 0.0018149530371190624, Validation Loss: 0.002398203196935356, Avg F-1: 0.7197088807821274, mIoU: 0.5650697827339173
# 100%|██████████| 89/89 [01:44<00:00,  1.17s/it]
# 100%|██████████| 20/20 [00:20<00:00,  1.02s/it]
# Epoch 21, Loss: 0.0017783272726293862, Validation Loss: 0.0023742633289657532, Avg F-1: 0.7246944516897201, mIoU: 0.571117702126503
# 100%|██████████| 89/89 [01:44<00:00,  1.17s/it]
# 100%|██████████| 20/20 [00:19<00:00,  1.00it/s]
# Epoch 22, Loss: 0.0017275910620483455, Validation Loss: 0.002473693829961121, Avg F-1: 0.7203377783298492, mIoU: 0.5661193311214447
# 100%|██████████| 89/89 [01:46<00:00,  1.20s/it]
# 100%|██████████| 20/20 [00:20<00:00,  1.02s/it]
# Epoch 23, Loss: 0.0016866411433000578, Validation Loss: 0.0025143130915239453, Avg F-1: 0.7094803959131241, mIoU: 0.5529415488243103
# 100%|██████████| 89/89 [01:43<00:00,  1.16s/it]
# 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Epoch 24, Loss: 0.0016405954773883137, Validation Loss: 0.0024816467659547923, Avg F-1: 0.729408261179924, mIoU: 0.5767811924219132
# 100%|██████████| 89/89 [01:45<00:00,  1.18s/it]
# 100%|██████████| 20/20 [00:21<00:00,  1.08s/it]
# Epoch 25, Loss: 0.0016082321945054645, Validation Loss: 0.002603234932757914, Avg F-1: 0.7092738568782806, mIoU: 0.5527077034115792
# 100%|██████████| 89/89 [01:44<00:00,  1.17s/it]
# 100%|██████████| 20/20 [00:21<00:00,  1.09s/it]
# Epoch 26, Loss: 0.0015462880098689976, Validation Loss: 0.0024982322123833, Avg F-1: 0.7205398470163346, mIoU: 0.5663466602563858
# 100%|██████████| 89/89 [01:44<00:00,  1.17s/it]
# 100%|██████████| 20/20 [00:20<00:00,  1.01s/it]
# Epoch 27, Loss: 0.0014962605645440603, Validation Loss: 0.0026079620118252935, Avg F-1: 0.7160126596689225, mIoU: 0.5608470305800438
# 100%|██████████| 89/89 [01:45<00:00,  1.19s/it]
# 100%|██████████| 20/20 [00:19<00:00,  1.00it/s]
# Epoch 28, Loss: 0.0014454158862759726, Validation Loss: 0.0025465449201874436, Avg F-1: 0.7280871838331222, mIoU: 0.5752559661865234
# 100%|██████████| 89/89 [01:44<00:00,  1.17s/it]
# 100%|██████████| 20/20 [00:21<00:00,  1.09s/it]
# Epoch 29, Loss: 0.0013910899333802334, Validation Loss: 0.002674853045027703, Avg F-1: 0.7223595231771469, mIoU: 0.568357989192009
#  40%|████      | 36/89 [00:44<01:05,  1.23s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-1476316bed12> in <cell line: 33>()
#      34     model.train()
#      35     epoch_loss = 0
# ---> 36     for images, masks, _ in tqdm(train_loader):
#      37         images = images.float().to(device)
#      38         masks = masks.float().to(device).unsqueeze(1)
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in __iter__(self)
#    1180
#    1181         try:
# -> 1182             for obj in iterable:
#    1183                 yield obj
#    1184                 # Update and possibly print the progressbar.
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1326
#    1327             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1328             idx, data = self._get_data()
#    1329             self._tasks_outstanding -= 1
#    1330             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1292         else:
#    1293             while True:
# -> 1294                 success, data = self._try_get_data()
#    1295                 if success:
#    1296                     return data
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1130         #   (bool: whether successfully get data, any: data if successful else None)
#    1131         try:
# -> 1132             data = self._data_queue.get(timeout=timeout)
#    1133             return (True, data)
#    1134         except Exception as e:
#
# /usr/lib/python3.10/multiprocessing/queues.py in get(self, block, timeout)
#     111                 if block:
#     112                     timeout = deadline - time.monotonic()
# --> 113                     if not self._poll(timeout):
#     114                         raise Empty
#     115                 elif not self._poll():
#
# /usr/lib/python3.10/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /usr/lib/python3.10/multiprocessing/connection.py in _poll(self, timeout)
#     422
#     423     def _poll(self, timeout):
# --> 424         r = wait([self], timeout)
#     425         return bool(r)
#     426
#
# /usr/lib/python3.10/multiprocessing/connection.py in wait(object_list, timeout)
#     929
#     930             while True:
# --> 931                 ready = selector.select(timeout)
#     932                 if ready:
#     933                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.10/selectors.py in select(self, timeout)
#     414         ready = []
#     415         try:
# --> 416             fd_event_list = self._selector.poll(timeout)
#     417         except InterruptedError:
#     418             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# #Test

# %%
import matplotlib.pyplot as plt
from torchvision.utils import save_image, make_grid
import numpy as np
import torch
from torch.utils.data import DataLoader, random_split
from PIL import Image

# %%
model.load_state_dict(torch.load('./best_model.pth'))
# Out:
# <All keys matched successfully>

# %%
#evaluate Test
# 모델을 평가 모드로 설정
model.eval()

# 점수 초기화
total_f1_score = 0.0
total_iou_score = 0.0
num_samples = 0

# 테스트 데이터셋에 대한 루프
for images, masks, _ in test_loader:
    with torch.no_grad():
        # 데이터를 장치에 로드
        images = images.float().to(device)
        masks = masks.float().to(device).unsqueeze(1)

        # 모델 예측
        outputs = model(images)

        # F1 점수와 IoU 점수 계산
        f1 = calculate_f1_score(outputs, masks)
        iou = calculate_iou(outputs, masks)
        total_f1_score += f1
        total_iou_score += iou
        num_samples += 1

# 평균 F1 점수와 IoU 점수 출력
avg_f1_score = total_f1_score / num_samples
avg_iou_score = total_iou_score / num_samples
print(f"Average F1 Score on Test Set: {avg_f1_score}")
print(f"Average IoU Score on Test Set: {avg_iou_score}")
# Out:
# Average F1 Score on Test Set: 0.725782522559166
# Average IoU Score on Test Set: 0.5722796529531479

# %%
#Print Test Mask
model.eval()

k = 1
f1_scores = []
iou_scores = []
for images, masks, real in test_loader:
    if k > 10:
        break
    with torch.no_grad():
        images = images.float().to(device)
        masks = masks.float().to(device).unsqueeze(1)
        outputs = model(images)

        # F1와 IoU 계산
        f1 = calculate_f1_score(outputs, masks)
        iou = calculate_iou(outputs, masks)
        f1_scores.append(f1)
        iou_scores.append(iou)

        print(f"#Test {k} | f1: {f1}, iou: {iou}")

        # 시각화
        img_cpu = real[0].cpu().numpy().transpose(1, 2, 0)  # 첫 번째 이미지 선택
        mask_cpu = masks[0].squeeze().cpu().numpy()           # 첫 번째 마스크 선택
        output_sigmoid = torch.sigmoid(outputs[0]).squeeze().cpu().numpy()  # 첫 번째 출력 선택, 채널 차원 제거
        plt.subplot(1, 3, 1)
        plt.imshow(img_cpu)
        plt.subplot(1, 3, 2)
        plt.imshow(mask_cpu, cmap='gray')
        plt.subplot(1, 3, 3)
        plt.imshow(output_sigmoid, cmap='gray')
        plt.show()
        k += 1
# Out:
# #Test 1 | f1: 0.7156879901885986, iou: 0.5593247413635254
# #Test 2 | f1: 0.7118271589279175, iou: 0.5549306869506836
# #Test 3 | f1: 0.7284237146377563, iou: 0.575546383857727
# #Test 4 | f1: 0.7273037433624268, iou: 0.5752207636833191
# #Test 5 | f1: 0.7341833114624023, iou: 0.5828795433044434
# #Test 6 | f1: 0.7352264523506165, iou: 0.5840640068054199
# #Test 7 | f1: 0.7324662804603577, iou: 0.580909252166748
# #Test 8 | f1: 0.7340279817581177, iou: 0.5819117426872253
# #Test 9 | f1: 0.7287210822105408, iou: 0.5750329494476318
# #Test 10 | f1: 0.7274767160415649, iou: 0.5746461153030396

# %% [markdown]
# #Experiments

# %%
pip install pyheif
# Out:
# Collecting pyheif
#   Downloading pyheif-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pyheif) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.0->pyheif) (2.21)
# Installing collected packages: pyheif
# Successfully installed pyheif-0.7.1

# %%
import pyheif

# %%
def heic_to_jpeg(heic_dir, jpeg_dir):

    heif_file = pyheif.read(heic_dir)

    image = Image.frombytes(
        heif_file.mode,
        heif_file.size,
        heif_file.data,
        "raw",
        heif_file.mode,
        heif_file.stride
        )

    print(heif_file)
    image.save(jpeg_dir,"JPEG")

# %%
heic_to_jpeg("/content/IMG_5076.heic", "/content/IMG_5076.jpeg")
# Out:
# <HeifFile 2806x3787 RGB with 31931984 bytes data>

# %%
# 단일 이미지에 대한 전처리 및 데이터 증강을 수행하는 함수
def preprocess_image(img_path, size=(256, 256)):
    image = cv2.imread(img_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # 데이터 증강 및 전처리 파이프라인
    transform = A.Compose([
        A.Resize(*size),
        A.Normalize(),
        ToTensorV2()
    ])

    # 변환 적용
    transformed = transform(image=image)
    return transformed['image']

# %%
# 단일 이미지를 검출하는 함수
def detect(jpeg_dir, model, device, save=True):
    # 이미지 전처리
    image = preprocess_image(jpeg_dir)

    # 모델 예측
    with torch.no_grad():
        image = image.float().unsqueeze(0).to(device)
        outputs = model(image)

    # 시각화
    pil_img = Image.open(jpeg_dir).convert('RGB').resize((256, 256), resample=Image.NEAREST)
    img_cpu = image.squeeze(0).cpu().numpy().transpose(1, 2, 0)
    output_sigmoid = torch.sigmoid(outputs).squeeze(0).cpu().numpy().squeeze()  # 첫 번째 차원 제거

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.imshow(pil_img)
    plt.title('Original Image')

    plt.subplot(1, 2, 2)
    plt.imshow(output_sigmoid, cmap='gray')  # 2차원 배열
    plt.title('Predicted Mask')
    plt.show()

# %%
detect("/content/IMG_5076.jpeg",model,device)

# %%
detect("./inputs/hand2_1.jpeg")
detect("./inputs/hand2_2.jpeg")
detect("./inputs/hand2_3.jpg")
detect("./inputs/hand2_4.jpg")

# %%
detect("./inputs/hand4_1.jpeg")
detect("./inputs/hand4_2.jpeg")
detect("./inputs/hand4_3.jpg")
detect("./inputs/hand4_4.jpg")
